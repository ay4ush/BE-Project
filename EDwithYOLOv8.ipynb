# %%
# !nvidia-smi
# Out:
# Sun Nov 19 17:36:43 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !ls
# Out:
# drive  runs  yolov8n-cls.pt  yolov8n.pt

# %%
DATA_DIR = 'drive/MyDrive/images'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.2/645.2 kB 7.2 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.212 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.9/78.2 GB disk)

# %%
from ultralytics import YOLO

# %%
import tensorflow as tf
if tf.test.is_gpu_available():
    print("GPU is available")
    # Allow GPU memory growth to prevent memory allocation issues
    physical_devices = tf.config.list_physical_devices('GPU')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
else:
    print("No GPU available")
# Out:
# WARNING:tensorflow:From <ipython-input-16-6c956844d0bb>:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU is available

# %%
# !yolo task=classify mode=train model = yolov8n-cls.pt data= 'drive/MyDrive/images' epochs = 10 imgsz = 64
# Out:
# Ultralytics YOLOv8.0.212 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls 'runs/classify/train3/weights'
# Out:
# best.pt  last.pt

# %%
# !yolo task = classify mode = val model= 'runs/classify/train3/weights/best.pt' data = 'drive/MyDrive/images'
# Out:
# Ultralytics YOLOv8.0.212 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1443847 parameters, 0 gradients, 3.3 GFLOPs
# train: /content/drive/MyDrive/images/train... found 3517 images in 7 classes ✅
# val: /content/drive/MyDrive/images/validation... found 829 images in 7 classes ✅
# test: None...
# val: Scanning /content/drive/MyDrive/images/validation... 829 images, 0 corrupt: 100% 829/829 [00:00<?, ?it/s]
#                classes   top1_acc   top5_acc: 100% 52/52 [00:02<00:00, 24.16it/s]
#                    all      0.511      0.959
# Speed: 0.0ms preprocess, 1.1ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs/classify/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task = classify mode = predict model = 'runs/classify/train3/weights/best.pt' conf = 0.25 source = "drive/MyDrive/images/validation/happy/32614.jpg"
# Out:
# Ultralytics YOLOv8.0.212 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1443847 parameters, 0 gradients, 3.3 GFLOPs
#
# image 1/1 /content/drive/MyDrive/images/validation/happy/32614.jpg: 64x64 happy 0.98, fear 0.01, neutral 0.01, disgust 0.00, surprise 0.00, 4.7ms
# Speed: 1.0ms preprocess, 4.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# Results saved to runs/classify/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo export model = 'runs/classify/train3/weights/best.pt' format = onnx
# Out:
# Ultralytics YOLOv8.0.212 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU (Intel Xeon 2.00GHz)
# YOLOv8n-cls summary (fused): 73 layers, 1443847 parameters, 0 gradients, 3.3 GFLOPs
#
# PyTorch: starting from 'runs/classify/train3/weights/best.pt' with input shape (1, 3, 64, 64) BCHW and output shape(s) (1, 7) (2.8 MB)
# requirements: Ultralytics requirement ['onnx>=1.12.0'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 71.4 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 8.8s, installed 1 package: ['onnx>=1.12.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.15.0 opset 17...
# ONNX: export success ✅ 9.1s, saved as 'runs/classify/train3/weights/best.onnx' (5.5 MB)
#
# Export complete (11.8s)
# Results saved to /content/runs/classify/train3/weights
# Predict:         yolo predict task=classify model=runs/classify/train3/weights/best.onnx imgsz=64
# ...

# %%
from google.colab import files
files.download('runs/classify/train3')

# %%
files.download('runs/classify/train3/')
